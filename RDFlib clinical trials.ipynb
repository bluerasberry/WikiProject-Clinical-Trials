# %% [markdown]
# # Import packages #

# %%
# !pip install sparqlwrapper
# Out:
# Requirement already satisfied: sparqlwrapper in /Users/lanerasberry/opt/anaconda3/lib/python3.9/site-packages (1.8.5)
# Requirement already satisfied: rdflib>=4.0 in /Users/lanerasberry/opt/anaconda3/lib/python3.9/site-packages (from sparqlwrapper) (6.1.1)
# Requirement already satisfied: setuptools in /Users/lanerasberry/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=4.0->sparqlwrapper) (58.0.4)
# Requirement already satisfied: pyparsing in /Users/lanerasberry/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=4.0->sparqlwrapper) (3.0.4)
# Requirement already satisfied: isodate in /Users/lanerasberry/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=4.0->sparqlwrapper) (0.6.1)
# Requirement already satisfied: six in /Users/lanerasberry/opt/anaconda3/lib/python3.9/site-packages (from isodate->rdflib>=4.0->sparqlwrapper) (1.16.0)

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
def select(query, service='https://query.wikidata.org/sparql'):
    sparql = SPARQLWrapper(service)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query().convert()
    return pd.json_normalize(result['results']['bindings'])

# %% [markdown]
# # Table of contents #

# %% [markdown]
# >
# 1 Model profiles
#
#     1.1 Clinical trials for Zika fever
#     1.2 Clinical trials using COVID-19 vaccine
#     1.3 Clinical trials at Vanderbilt University
#     1.4 Clinical trials with Julie McElrath as principal investigator
#     1.5 Clinical trials funded by Patient-Centered Outcomes Research Institute
#
# 2 Topics by count of clinical trials
#
#     2.1 Medical conditions
#     2.2 Research interventions
#     2.3 Research sites
#     2.4 Principal investigators
#     2.5 Funders
#
# 3 Organizational affiliations
#
#     3.1 Clinical trials with principal investigator and their affiliation
#     3.2 Clinical trials where principal investigator has Vanderbilt University affiliation
#     3.3 Chart of organizations by count of clinical trials
#     3.4 Clinical trials where the sponsor was Pfizer
#
# 4 Researcher demographics
#
#     4.1 Count of principal investigators by gender
#     4.2 Clinical trials where the principal investigator is female
#     4.3 Principal investigators by occupation
#
# 5 Scope of Wikidata's clinical trials content
#
#     5.1 List of clinical trials
#     5.2 Count of clinical trials
#     5.3 Most common properties applied to clinical trials
#     5.4 Count of statements in clinical trial records
#     5.5 Count of trial records in Wikidata per clinical trial registry
#
# >

# %% [markdown]
# # 1 Model profiles #

# %% [markdown]
# ## 1.1 Clinical trials for Zika fever ##

# %%
query_string = """
SELECT ?trial ?trialLabel  WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P2175 wd:Q8071861. }
  UNION
  { ?trial wdt:P2175 wd:Q27043680. }

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_for_Zika_fever.csv")
result
# Out:
#    trial.type                               trial.value trialLabel.xml:lang  \
# 0         uri  http://www.wikidata.org/entity/Q60563291                  en
# 1         uri  http://www.wikidata.org/entity/Q60563296                  en
# 2         uri  http://www.wikidata.org/entity/Q60563298                  en
# 3         uri  http://www.wikidata.org/entity/Q60563300                  en
# 4         uri  http://www.wikidata.org/entity/Q60563302                  en
# 5         uri  http://www.wikidata.org/entity/Q60563303                  en
# 6         uri  http://www.wikidata.org/entity/Q60563306                  en
# 7         uri  http://www.wikidata.org/entity/Q60563307                  en
# 8         uri  http://www.wikidata.org/entity/Q60563313                  en
# 9         uri  http://www.wikidata.org/entity/Q60563322                  en
# 10        uri  http://www.wikidata.org/entity/Q60563329                  en
# 11        uri  http://www.wikidata.org/entity/Q60563331                  en
# 12        uri  http://www.wikidata.org/entity/Q60563332                  en
# 13        uri  http://www.wikidata.org/entity/Q60563338                  en
# 14        uri  http://www.wikidata.org/entity/Q60563344                  en
# 15        uri  http://www.wikidata.org/entity/Q60563348                  en
# 16        uri  http://www.wikidata.org/entity/Q60563350                  en
# 17        uri  http://www.wikidata.org/entity/Q60563356                  en
#
#    trialLabel.type                                   trialLabel.value
# 0          literal          Dermatologic Manifestations of Zika Virus
# 1          literal  Understanding Excretion and Infectivity of Zik...
# 2          literal                     ZIKA Vaccine in Naive Subjects
# 3          literal  Study in Healthy Volunteers Evaluating Safety ...
# 4          literal  Sensorimotor Outcomes of Children Exposed to F...
# 5          literal  Phase I, Randomized, Double-blinded, Placebo-C...
# 6          literal  A Phase 1, First-in-human, Double-blinded, Ran...
# 7          literal  Zika Virus Purified Inactivated Vaccine (ZPIV)...
# 8          literal  Randomized, Placebo-controlled, Observer-blind...
# 9          literal  Efficacy of Aquatic Physiotherapy in Children ...
# 10         literal  Safety and Tolerability of an Antibody Against...
# 11         literal  Vertical Exposure to Zika Virus and Its Conseq...
# 12         literal  Safety and Tolerability of an Antibody Against...
# 13         literal                  ZIKAlliance Natural History Study
# 14         literal  Evaluation of the Clinical Performance of the ...
# 15         literal  Neurodevelopment Outcome of Newborns Exposed t...
# 16         literal  Effect of a Posture Adapter for 12 to 24-month...
# 17         literal             Applying Wolbachia to Eliminate Dengue

# %% [markdown]
# ## 1.2 Clinical trials using COVID-19 vaccine ##

# %%
query_string = """
SELECT ?trial ?trialLabel  WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  # ?trial wdt:P4844 ?intervention. 
  # ?intervention wdt:P31/wdt:P279* wd:Q87719492 .

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_using_COVID-19_vaccine.csv")
result
# Out:
#    trial.type                                trial.value trialLabel.xml:lang  \
# 0         uri   http://www.wikidata.org/entity/Q87775009                  en
# 1         uri   http://www.wikidata.org/entity/Q87931195                  en
# 2         uri   http://www.wikidata.org/entity/Q89154124                  en
# 3         uri   http://www.wikidata.org/entity/Q92274099                  en
# 4         uri   http://www.wikidata.org/entity/Q93328935                  en
# 5         uri   http://www.wikidata.org/entity/Q93328984                  en
# 6         uri   http://www.wikidata.org/entity/Q94234839                  en
# 7         uri   http://www.wikidata.org/entity/Q95056331                  en
# 8         uri   http://www.wikidata.org/entity/Q95718298                  en
# 9         uri   http://www.wikidata.org/entity/Q95719961                  en
# 10        uri   http://www.wikidata.org/entity/Q97046521                  en
# 11        uri   http://www.wikidata.org/entity/Q98710332                  en
# 12        uri  http://www.wikidata.org/entity/Q107401571                  en
# 13        uri  http://www.wikidata.org/entity/Q107401573                  en
# 14        uri  http://www.wikidata.org/entity/Q107401574                  en
# 15        uri  http://www.wikidata.org/entity/Q107401604                  en
# 16        uri  http://www.wikidata.org/entity/Q107401604                  en
# 17        uri  http://www.wikidata.org/entity/Q107401607                  en
# 18        uri  http://www.wikidata.org/entity/Q107401619                  en
#
#    trialLabel.type                                   trialLabel.value
# 0          literal  Safety and Immunogenicity Study of 2019-nCoV V...
# 1          literal  A Single-center,Open-label，Dose-escalating Pha...
# 2          literal   A Study of a Candidate COVID-19 Vaccine (COV001)
# 3          literal  Safety and Immunogenicity Study of Inactivated...
# 4          literal  Evaluation of the Safety and Immunogenicity of...
# 5          literal  Study to Describe the Safety, Tolerability, Im...
# 6          literal  Safety and Immunogenicity Study of Inactivated...
# 7          literal  Phase I/II Clinical Trial of Recombinant Novel...
# 8          literal           Investigating a Vaccine Against COVID-19
# 9          literal  Dose-Confirmation Study to Evaluate the Safety...
# 10         literal  An Open Study of the Safety, Tolerability and ...
# 11         literal  A Randomised, Controlled, Phase 1 Study to Eva...
# 12         literal  Delayed Heterologous SARS-CoV-2 Vaccine Dosing...
# 13         literal  Safety and Immunogenicity Study of a SARS-CoV-...
# 14         literal  A Study of SARS CoV-2 Infection and Potential ...
# 15         literal  COVID19 SARS Vaccinations: Systemic Allergic R...
# 16         literal  COVID19 SARS Vaccinations: Systemic Allergic R...
# 17         literal  A Study to Evaluate the Safety, Reactogenicity...
# 18         literal  A Trial of the Safety and Immunogenicity of th...

# %% [markdown]
#  ## 1.3 Clinical trials at Vanderbilt University ##

# %%
query_string = """
SELECT ?trial ?trialLabel WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P6153 [ wdt:P749* wd:Q29052  ] .}
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_at_Vanderbilt_University.csv")
result
# Out:
#      trial.type                                trial.value  \
# 0           uri   http://www.wikidata.org/entity/Q63807967
# 1           uri   http://www.wikidata.org/entity/Q63807976
# 2           uri   http://www.wikidata.org/entity/Q63807978
# 3           uri   http://www.wikidata.org/entity/Q63807982
# 4           uri   http://www.wikidata.org/entity/Q63807992
# ...         ...                                        ...
# 1386        uri   http://www.wikidata.org/entity/Q96759632
# 1387        uri   http://www.wikidata.org/entity/Q98605059
# 1388        uri  http://www.wikidata.org/entity/Q105788657
# 1389        uri  http://www.wikidata.org/entity/Q106967353
# 1390        uri  http://www.wikidata.org/entity/Q107507954
#
#      trialLabel.xml:lang trialLabel.type  \
# 0                     en         literal
# 1                     en         literal
# 2                     en         literal
# 3                     en         literal
# 4                     en         literal
# ...                  ...             ...
# 1386                  en         literal
# 1387                  en         literal
# 1388                  en         literal
# 1389                  en         literal
# 1390                  en         literal
#
#                                        trialLabel.value
# 0     Temozolomide With or Without Veliparib in Trea...
# 1     Combination Chemotherapy With or Without Blina...
# 2     Brentuximab Vedotin or Crizotinib and Combinat...
# 3          Neratinib HER Mutation Basket Study (SUMMIT)
# 4     Rituximab and Combination Chemotherapy With or...
# ...                                                 ...
# 1386  Predicting the Quality of Response to Specific...
# 1387  Hypofractionated Radiotherapy Followed by Imme...
# 1388  A Study of DS-6000a in Subjects With Advanced ...
# 1389  Digital-storytelling Intervention for Rural-dw...
# 1390            Angelman Syndrome Natural History Study
#
# [1391 rows x 5 columns]

# %% [markdown]
# ## 1.4 Clinical trials with Julie McElrath as principal investigator ##

# %%
query_string = """
SELECT ?trial ?trialLabel WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P8329 wd:Q22006776 .}
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_with_Julie_McElrath_as_principal_investigator.csv")
result
# Out:
#    trial.type                               trial.value trialLabel.xml:lang  \
# 0         uri  http://www.wikidata.org/entity/Q63573557                  en
# 1         uri  http://www.wikidata.org/entity/Q64796540                  en
# 2         uri  http://www.wikidata.org/entity/Q66032588                  en
# 3         uri  http://www.wikidata.org/entity/Q66034272                  en
# 4         uri  http://www.wikidata.org/entity/Q66034726                  en
# 5         uri  http://www.wikidata.org/entity/Q66040660                  en
# 6         uri  http://www.wikidata.org/entity/Q66040667                  en
# 7         uri  http://www.wikidata.org/entity/Q66040669                  en
# 8         uri  http://www.wikidata.org/entity/Q66040681                  en
# 9         uri  http://www.wikidata.org/entity/Q66040865                  en
# 10        uri  http://www.wikidata.org/entity/Q66402097                  en
# 11        uri  http://www.wikidata.org/entity/Q76981856                  en
#
#    trialLabel.type                                   trialLabel.value
# 0          literal  A Randomized, Double-blinded, Placebo-controll...
# 1          literal  A Phase I Trial to Evaluate the Safety and Imm...
# 2          literal  Safety of and Immune Response to an HIV-1 Vacc...
# 3          literal  Safety of and Immune Response to an HIV-1 DNA ...
# 4          literal                        Resistance to HIV Infection
# 5          literal  A Phase I, Multicenter, Randomized, Double-Bli...
# 6          literal  A Phase I, Multicenter, Randomized, Double-Bli...
# 7          literal  A Phase I, Randomized, Double-Blind, Placebo-C...
# 8          literal  A Phase II Clinical Trial to Evaluate the Immu...
# 9          literal  A Phase I, Multicenter, Randomized, Double-Bli...
# 10         literal  Evaluating the Safety, Pharmacokinetics, and A...
# 11         literal  Evaluating the Safety and Immunogenicity of HI...

# %% [markdown]
# ## 1.5 Clinical trials funded by Patient-Centered Outcomes Research Institute ##

# %%
query_string = """
SELECT ?trial ?trialLabel ?link WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P8324 wd:Q7144950 .}
  UNION
  { ?trial wdt:P859 wd:Q7144950 .}
  # ?trial ?link wd:Q7144950 .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_funded_by_Patient-Centered_Outcomes_Research_Institute.csv")
result
# Out:
#     trial.type                               trial.value link.type  \
# 0          uri  http://www.wikidata.org/entity/Q64606545       uri
# 1          uri  http://www.wikidata.org/entity/Q64606545       uri
# 2          uri  http://www.wikidata.org/entity/Q64607589       uri
# 3          uri  http://www.wikidata.org/entity/Q64607589       uri
# 4          uri  http://www.wikidata.org/entity/Q64611137       uri
# ..         ...                                       ...       ...
# 193        uri  http://www.wikidata.org/entity/Q64606385       uri
# 194        uri  http://www.wikidata.org/entity/Q64606385       uri
# 195        uri  http://www.wikidata.org/entity/Q64606544       uri
# 196        uri  http://www.wikidata.org/entity/Q64606544       uri
# 197        uri  http://www.wikidata.org/entity/Q64606544       uri
#
#                                     link.value trialLabel.xml:lang  \
# 0     http://www.wikidata.org/prop/direct/P767                  en
# 1    http://www.wikidata.org/prop/direct/P8324                  en
# 2     http://www.wikidata.org/prop/direct/P767                  en
# 3    http://www.wikidata.org/prop/direct/P8324                  en
# 4    http://www.wikidata.org/prop/direct/P8324                  en
# ..                                         ...                 ...
# 193   http://www.wikidata.org/prop/direct/P767                  en
# 194  http://www.wikidata.org/prop/direct/P8324                  en
# 195   http://www.wikidata.org/prop/direct/P767                  en
# 196   http://www.wikidata.org/prop/direct/P859                  en
# 197  http://www.wikidata.org/prop/direct/P8324                  en
#
#     trialLabel.type                                   trialLabel.value
# 0           literal  Patient Assisted Intervention for Neuropathy: ...
# 1           literal  Patient Assisted Intervention for Neuropathy: ...
# 2           literal  BEnefits of Stroke Treatment Delivered Using a...
# 3           literal  BEnefits of Stroke Treatment Delivered Using a...
# 4           literal  Assessment of a Personalized Health Care Inter...
# ..              ...                                                ...
# 193         literal  Optimizing Health Outcomes in Patients With Sy...
# 194         literal  Optimizing Health Outcomes in Patients With Sy...
# 195         literal  Long Term Outcomes of Lumbar Epidural Steroid ...
# 196         literal  Long Term Outcomes of Lumbar Epidural Steroid ...
# 197         literal  Long Term Outcomes of Lumbar Epidural Steroid ...
#
# [198 rows x 7 columns]

# %% [markdown]
# # 2 Topics by count of clinical trials #

# %% [markdown]
# ## 2.1 Medical conditions ##

# %%
query_string = """
SELECT DISTINCT ?condition ?conditionLabel (COUNT(?trial) AS ?count) 
WHERE
{
   # ?trial p:P31/ps:P31/wdt:P279* wd:Q30612.
   # ?trial wdt:P1050 ?condition .
   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?condition ?conditionLabel ?count 
ORDER BY DESC(?count)
LIMIT 100"""


result=select(query_string)
result.to_csv("Medical_conditions.csv")
result
# Out:
#    condition.type                         condition.value  \
# 0             uri   http://www.wikidata.org/entity/Q12206
# 1             uri  http://www.wikidata.org/entity/Q179630
# 2             uri   http://www.wikidata.org/entity/Q33525
# 3             uri   http://www.wikidata.org/entity/Q29496
# 4             uri  http://www.wikidata.org/entity/Q208414
# ..            ...                                     ...
# 95            uri  http://www.wikidata.org/entity/Q189470
# 96            uri  http://www.wikidata.org/entity/Q938205
# 97            uri  http://www.wikidata.org/entity/Q103177
# 98            uri  http://www.wikidata.org/entity/Q124292
# 99            uri  http://www.wikidata.org/entity/Q220570
#
#    conditionLabel.xml:lang conditionLabel.type  \
# 0                       en             literal
# 1                       en             literal
# 2                       en             literal
# 3                       en             literal
# 4                       en             literal
# ..                     ...                 ...
# 95                      en             literal
# 96                      en             literal
# 97                      en             literal
# 98                      en             literal
# 99                      en             literal
#
#                  conditionLabel.value  \
# 0                            diabetes
# 1                            syndrome
# 2                           carcinoma
# 3                            leukemia
# 4                            lymphoma
# ..                                ...
# 95                            fistula
# 96                      neuroblastoma
# 97  severe acute respiratory syndrome
# 98                 cholangiocarcinoma
# 99                 pulmonary embolism
#
#                               count.datatype count.type count.value
# 0   http://www.w3.org/2001/XMLSchema#integer    literal       10093
# 1   http://www.w3.org/2001/XMLSchema#integer    literal        7433
# 2   http://www.w3.org/2001/XMLSchema#integer    literal        5613
# 3   http://www.w3.org/2001/XMLSchema#integer    literal        5018
# 4   http://www.w3.org/2001/XMLSchema#integer    literal        4813
# ..                                       ...        ...         ...
# 95  http://www.w3.org/2001/XMLSchema#integer    literal         498
# 96  http://www.w3.org/2001/XMLSchema#integer    literal         498
# 97  http://www.w3.org/2001/XMLSchema#integer    literal         497
# 98  http://www.w3.org/2001/XMLSchema#integer    literal         490
# 99  http://www.w3.org/2001/XMLSchema#integer    literal         480
#
# [100 rows x 8 columns]

# %% [markdown]
# ## 2.2 Research interventions ##

# %%
query_string = """
SELECT DISTINCT ?intervention ?interventionLabel (COUNT(?trial) AS ?count) 
WHERE
{
   # ?trial p:P31/ps:P31/wdt:P279* wd:Q30612.
   # ?trial wdt:P4844 ?intervention .
   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?intervention ?interventionLabel ?count 
ORDER BY DESC(?count)"""

result=select(query_string)
result.to_csv("Research_interventions.csv")
result
# Out:
#      intervention.type                        intervention.value  \
# 0                  uri    http://www.wikidata.org/entity/Q408524
# 1                  uri    http://www.wikidata.org/entity/Q423762
# 2                  uri  http://www.wikidata.org/entity/Q50430271
# 3                  uri    http://www.wikidata.org/entity/Q412415
# 4                  uri    http://www.wikidata.org/entity/Q415588
# ...                ...                                       ...
# 2486               uri  http://www.wikidata.org/entity/Q50265665
# 2487               uri     http://www.wikidata.org/entity/Q46994
# 2488               uri   http://www.wikidata.org/entity/Q7598360
# 2489               uri   http://www.wikidata.org/entity/Q6576792
# 2490               uri   http://www.wikidata.org/entity/Q4086927
#
#      interventionLabel.xml:lang interventionLabel.type  \
# 0                            en                literal
# 1                            en                literal
# 2                            en                literal
# 3                            en                literal
# 4                            en                literal
# ...                         ...                    ...
# 2486                         en                literal
# 2487                         en                literal
# 2488                         en                literal
# 2489                         en                literal
# 2490                         en                literal
#
#      interventionLabel.value                            count.datatype  \
# 0      (RS)-cyclophosphamide  http://www.w3.org/2001/XMLSchema#integer
# 1                 paclitaxel  http://www.w3.org/2001/XMLSchema#integer
# 2      Anesthetics, Combined  http://www.w3.org/2001/XMLSchema#integer
# 3                  cisplatin  http://www.w3.org/2001/XMLSchema#integer
# 4                carboplatin  http://www.w3.org/2001/XMLSchema#integer
# ...                      ...                                       ...
# 2486                 insulin  http://www.w3.org/2001/XMLSchema#integer
# 2487              telehealth  http://www.w3.org/2001/XMLSchema#integer
# 2488        standard of care  http://www.w3.org/2001/XMLSchema#integer
# 2489        online community  http://www.w3.org/2001/XMLSchema#integer
# 2490         prostate biopsy  http://www.w3.org/2001/XMLSchema#integer
#
#      count.type count.value
# 0       literal        5180
# 1       literal        3188
# 2       literal        3182
# 3       literal        2625
# 4       literal        2323
# ...         ...         ...
# 2486    literal           1
# 2487    literal           1
# 2488    literal           1
# 2489    literal           1
# 2490    literal           1
#
# [2491 rows x 8 columns]

# %% [markdown]
# ## 2.3 Research sites ##

# %%
query_string = """
SELECT DISTINCT ?research_site ?research_siteLabel (COUNT(?trial) AS ?count)  WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P6153 ?research_site . }
  UNION
  { ?trial wdt:P6153 [wdt:P749 ?research_site] . }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?research_site ?research_siteLabel ?count
ORDER BY DESC(?count)"""

result=select(query_string)
result.to_csv("Research_sites.csv")
result
# Out:
#      research_site.type                       research_site.value  \
# 0                   uri   http://www.wikidata.org/entity/Q7906562
# 1                   uri    http://www.wikidata.org/entity/Q184478
# 2                   uri   http://www.wikidata.org/entity/Q7140719
# 3                   uri   http://www.wikidata.org/entity/Q1130172
# 4                   uri    http://www.wikidata.org/entity/Q777403
# ...                 ...                                       ...
# 4252                uri     http://www.wikidata.org/entity/Q45312
# 4253                uri   http://www.wikidata.org/entity/Q8002474
# 4254                uri   http://www.wikidata.org/entity/Q3113883
# 4255                uri  http://www.wikidata.org/entity/Q55680455
# 4256                uri    http://www.wikidata.org/entity/Q902397
#
#      research_siteLabel.xml:lang research_siteLabel.type  \
# 0                             en                 literal
# 1                             en                 literal
# 2                             en                 literal
# 3                             en                 literal
# 4                             en                 literal
# ...                          ...                     ...
# 4252                          en                 literal
# 4253                          en                 literal
# 4254                          en                 literal
# 4255                          en                 literal
# 4256                          en                 literal
#
#                                research_siteLabel.value  \
# 0                           VA Boston Healthcare System
# 1                              University of California
# 2                                   Partners HealthCare
# 3                                           Mayo Clinic
# 4                    Washington University in St. Louis
# ...                                                 ...
# 4252                     King Edward Medical University
# 4253                                  Wilkes University
# 4254                        Ministry of Health of Spain
# 4255  General Secretariat for Scientific Policy Coor...
# 4256                                    Cardinal Health
#
#                                 count.datatype count.type count.value
# 0     http://www.w3.org/2001/XMLSchema#integer    literal        5369
# 1     http://www.w3.org/2001/XMLSchema#integer    literal        4021
# 2     http://www.w3.org/2001/XMLSchema#integer    literal        3927
# 3     http://www.w3.org/2001/XMLSchema#integer    literal        3511
# 4     http://www.w3.org/2001/XMLSchema#integer    literal        3241
# ...                                        ...        ...         ...
# 4252  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 4253  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 4254  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 4255  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 4256  http://www.w3.org/2001/XMLSchema#integer    literal           1
#
# [4257 rows x 8 columns]

# %% [markdown]
# ## 2.4 Principal investigators ##

# %%
query_string = """#defaultView:BubbleChart
SELECT (COUNT(DISTINCT ?trial) AS ?count) ?PI ?PILabel 
WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P8329 ?PI .}

  { ?PI wdt:P108 ?org }  
  UNION
  { ?PI wdt:P1416 ?org }  

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?PI ?PILabel 
ORDER BY DESC(?count)"""

result=select(query_string)
result.to_csv("Principal_investigators.csv")
result
# Out:
#     PI.type                                  PI.value PILabel.xml:lang  \
# 0       uri  http://www.wikidata.org/entity/Q91133737               en
# 1       uri  http://www.wikidata.org/entity/Q90057565               en
# 2       uri  http://www.wikidata.org/entity/Q42415822               en
# 3       uri  http://www.wikidata.org/entity/Q91133228               en
# 4       uri  http://www.wikidata.org/entity/Q88027010               en
# ..      ...                                       ...              ...
# 373     uri  http://www.wikidata.org/entity/Q83557098               en
# 374     uri  http://www.wikidata.org/entity/Q88029228               en
# 375     uri  http://www.wikidata.org/entity/Q88032988               en
# 376     uri  http://www.wikidata.org/entity/Q89234636               en
# 377     uri  http://www.wikidata.org/entity/Q89503711               en
#
#     PILabel.type                 PILabel.value  \
# 0        literal            Italo O. Biaggioni
# 1        literal                Nancy J. Brown
# 2        literal                 Satish R. Raj
# 3        literal             Barbara A. Murphy
# 4        literal   Anuradha Bapsi Chakravarthy
# ..           ...                           ...
# 373      literal                 Autumn Kujawa
# 374      literal  Myrick Clements Shinall, Jr.
# 375      literal                  Dan M. Roden
# 376      literal             Bryan E. Shepherd
# 377      literal       Jonathan Andrew Kropski
#
#                                count.datatype count.type count.value
# 0    http://www.w3.org/2001/XMLSchema#integer    literal          33
# 1    http://www.w3.org/2001/XMLSchema#integer    literal          22
# 2    http://www.w3.org/2001/XMLSchema#integer    literal          19
# 3    http://www.w3.org/2001/XMLSchema#integer    literal          19
# 4    http://www.w3.org/2001/XMLSchema#integer    literal          18
# ..                                        ...        ...         ...
# 373  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 374  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 375  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 376  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 377  http://www.w3.org/2001/XMLSchema#integer    literal           1
#
# [378 rows x 8 columns]

# %% [markdown]
# ## 2.5 Funders ##

# %%
query_string = """
SELECT DISTINCT ?funder ?funderLabel (COUNT(?trial) AS ?count) 
WHERE
{
   # ?trial p:P31/ps:P31/wdt:P279* wd:Q30612.
  { ?trial wdt:P859 ?funder .}
  UNION
  { ?trial wdt:P8324 ?funder .}
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?funder ?funderLabel ?count 
ORDER BY DESC(?count)"""

result=select(query_string)
result.to_csv("Funders.csv")
result
# Out:
#      funder.type                              funder.value  \
# 0            uri    http://www.wikidata.org/entity/Q212322
# 1            uri    http://www.wikidata.org/entity/Q507154
# 2            uri    http://www.wikidata.org/entity/Q212646
# 3            uri   http://www.wikidata.org/entity/Q1418766
# 4            uri    http://www.wikidata.org/entity/Q266423
# ...          ...                                       ...
# 3042         uri  http://www.wikidata.org/entity/Q98652284
# 3043         uri  http://www.wikidata.org/entity/Q30253359
# 3044         uri   http://www.wikidata.org/entity/Q1075148
# 3045         uri  http://www.wikidata.org/entity/Q65076661
# 3046         uri  http://www.wikidata.org/entity/Q91485932
#
#      funderLabel.xml:lang funderLabel.type  \
# 0                      en          literal
# 1                      en          literal
# 2                      en          literal
# 3                      en          literal
# 4                      en          literal
# ...                   ...              ...
# 3042                   en          literal
# 3043                   en          literal
# 3044                   en          literal
# 3045                   en          literal
# 3046                   en          literal
#
#                          funderLabel.value  \
# 0                          GlaxoSmithKline
# 1                                 Novartis
# 2                            Roche Holding
# 3      National Taiwan University Hospital
# 4                     Bristol-Myers Squibb
# ...                                    ...
# 3042        Walvax Biotechnology Co., Ltd.
# 3043  Public Health Foundation Enterprises
# 3044   University of California, Riverside
# 3045       St. Luke's Boise Medical Center
# 3046                     Debra L. Friedman
#
#                                 count.datatype count.type count.value
# 0     http://www.w3.org/2001/XMLSchema#integer    literal        3359
# 1     http://www.w3.org/2001/XMLSchema#integer    literal        2206
# 2     http://www.w3.org/2001/XMLSchema#integer    literal        1821
# 3     http://www.w3.org/2001/XMLSchema#integer    literal        1679
# 4     http://www.w3.org/2001/XMLSchema#integer    literal        1162
# ...                                        ...        ...         ...
# 3042  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 3043  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 3044  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 3045  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 3046  http://www.w3.org/2001/XMLSchema#integer    literal           1
#
# [3047 rows x 8 columns]

# %% [markdown]
# # 3 Organizational affiliations #

# %% [markdown]
# ## 3.1 Clinical trials with principal investigator and their affiliation ##

# %%
query_string = """
SELECT ?trial ?trialLabel ?PI ?PILabel ?org ?orgLabel  WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P8329 ?PI .}

  { ?PI wdt:P108 ?org }  
  UNION
  { ?PI wdt:P1416 ?org }  

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_with_principal_investigator_and_their_affiliation.csv")
result
# Out:
#      trial.type                               trial.value PI.type  \
# 0           uri  http://www.wikidata.org/entity/Q65466006     uri
# 1           uri  http://www.wikidata.org/entity/Q64149990     uri
# 2           uri  http://www.wikidata.org/entity/Q64801405     uri
# 3           uri  http://www.wikidata.org/entity/Q64662092     uri
# 4           uri  http://www.wikidata.org/entity/Q64662092     uri
# ...         ...                                       ...     ...
# 2216        uri  http://www.wikidata.org/entity/Q63397726     uri
# 2217        uri  http://www.wikidata.org/entity/Q63013312     uri
# 2218        uri  http://www.wikidata.org/entity/Q61909920     uri
# 2219        uri  http://www.wikidata.org/entity/Q62025113     uri
# 2220        uri  http://www.wikidata.org/entity/Q61969449     uri
#
#                                       PI.value org.type  \
# 0     http://www.wikidata.org/entity/Q47161235      uri
# 1     http://www.wikidata.org/entity/Q47493038      uri
# 2     http://www.wikidata.org/entity/Q47493038      uri
# 3     http://www.wikidata.org/entity/Q47502872      uri
# 4     http://www.wikidata.org/entity/Q47502872      uri
# ...                                        ...      ...
# 2216  http://www.wikidata.org/entity/Q91133311      uri
# 2217  http://www.wikidata.org/entity/Q91133452      uri
# 2218  http://www.wikidata.org/entity/Q91133485      uri
# 2219  http://www.wikidata.org/entity/Q91133485      uri
# 2220  http://www.wikidata.org/entity/Q91133646      uri
#
#                                     org.value trialLabel.xml:lang  \
# 0       http://www.wikidata.org/entity/Q29052                  en
# 1       http://www.wikidata.org/entity/Q29052                  en
# 2       http://www.wikidata.org/entity/Q29052                  en
# 3       http://www.wikidata.org/entity/Q29052                  en
# 4     http://www.wikidata.org/entity/Q7914455                  en
# ...                                       ...                 ...
# 2216    http://www.wikidata.org/entity/Q29052                  en
# 2217    http://www.wikidata.org/entity/Q29052                  en
# 2218    http://www.wikidata.org/entity/Q29052                  en
# 2219    http://www.wikidata.org/entity/Q29052                  en
# 2220    http://www.wikidata.org/entity/Q29052                  en
#
#      trialLabel.type                                   trialLabel.value  \
# 0            literal  Pediatric Acute Kidney Injury (AKI) Retrospect...
# 1            literal    Levocarnitine for Dry Eye in Sjogren's Syndrome
# 2            literal  Memantine for the Treatment of Cognitive Impai...
# 3            literal  Reduced Calorie Diet Intervention in Kidney Tr...
# 4            literal  Reduced Calorie Diet Intervention in Kidney Tr...
# ...              ...                                                ...
# 2216         literal     Collaborative Assessment of ICU Recovery Needs
# 2217         literal     Metabolism-informed Care for Smoking Cessation
# 2218         literal  Assessment of Duodenal Epithelial Integrity in...
# 2219         literal  Botox or Botox With Esophageal Dilation in Pat...
# 2220         literal  Ticagrelor in Severe Community Acquired Pneumonia
#
#      PILabel.xml:lang PILabel.type       PILabel.value orgLabel.xml:lang  \
# 0                  en      literal  Sara L. Van Driest                en
# 1                  en      literal  Leslie J. Crofford                en
# 2                  en      literal  Leslie J. Crofford                en
# 3                  en      literal   Kelly A. Birdwell                en
# 4                  en      literal   Kelly A. Birdwell                en
# ...               ...          ...                 ...               ...
# 2216               en      literal      Carla M. Sevin                en
# 2217               en      literal    Dawn M. Beaulieu                en
# 2218               en      literal   Dhyanesh A. Patel                en
# 2219               en      literal   Dhyanesh A. Patel                en
# 2220               en      literal   Gordon R. Bernard                en
#
#      orgLabel.type                        orgLabel.value
# 0          literal                 Vanderbilt University
# 1          literal                 Vanderbilt University
# 2          literal                 Vanderbilt University
# 3          literal                 Vanderbilt University
# 4          literal  Vanderbilt University Medical Center
# ...            ...                                   ...
# 2216       literal                 Vanderbilt University
# 2217       literal                 Vanderbilt University
# 2218       literal                 Vanderbilt University
# 2219       literal                 Vanderbilt University
# 2220       literal                 Vanderbilt University
#
# [2221 rows x 15 columns]

# %% [markdown]
# ## 3.2 Clinical trials where principal investigator has Vanderbilt University affiliation ##

# %%
query_string = """
# Q29052 is Vanderbilt University
PREFIX target: <http://www.wikidata.org/entity/Q29052>

SELECT ?trial ?trialLabel ?PI ?PILabel  WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P8329 ?PI .}

  { ?PI wdt:P108 [ wdt:P749* target: ] }  
  UNION
  { ?PI wdt:P1416 [ wdt:P749* target: ] }  

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_where_principal_investigator_has_Vanderbilt_University_affiliation.csv")
result
# Out:
#      PI.type                                  PI.value trial.type  \
# 0        uri   http://www.wikidata.org/entity/Q4734737        uri
# 1        uri   http://www.wikidata.org/entity/Q4734737        uri
# 2        uri   http://www.wikidata.org/entity/Q4734737        uri
# 3        uri   http://www.wikidata.org/entity/Q4734737        uri
# 4        uri   http://www.wikidata.org/entity/Q4734737        uri
# ...      ...                                       ...        ...
# 1903     uri  http://www.wikidata.org/entity/Q83451321        uri
# 1904     uri  http://www.wikidata.org/entity/Q89166741        uri
# 1905     uri  http://www.wikidata.org/entity/Q56950496        uri
# 1906     uri  http://www.wikidata.org/entity/Q83451296        uri
# 1907     uri  http://www.wikidata.org/entity/Q88325763        uri
#
#                                    trial.value trialLabel.xml:lang  \
# 0     http://www.wikidata.org/entity/Q63829569                  en
# 1     http://www.wikidata.org/entity/Q63830668                  en
# 2     http://www.wikidata.org/entity/Q64151795                  en
# 3     http://www.wikidata.org/entity/Q64719736                  en
# 4     http://www.wikidata.org/entity/Q64719824                  en
# ...                                        ...                 ...
# 1903  http://www.wikidata.org/entity/Q83805784                  en
# 1904  http://www.wikidata.org/entity/Q86283322                  en
# 1905  http://www.wikidata.org/entity/Q86291220                  en
# 1906  http://www.wikidata.org/entity/Q92549531                  en
# 1907  http://www.wikidata.org/entity/Q97045784                  en
#
#      trialLabel.type                                   trialLabel.value  \
# 0            literal  Oxidative Stress in Chronic Kidney Disease: Di...
# 1            literal  The Measurement of Insulin Resistance in Perit...
# 2            literal         Tissue Sodium in Pre-hypertensive Patients
# 3            literal  Vitamin D, Insulin Resistance and Inflammation...
# 4            literal  Omega-3 Fatty Acid Administration in Dialysis ...
# ...              ...                                                ...
# 1903         literal  Neuroplasticity-Based Cognitive Remediation fo...
# 1904         literal  Optimizing Psychosocial Treatment of Interstit...
# 1905         literal  Pharmacologic Modulation of Hippocampal Activi...
# 1906         literal  Enhancing Social Competence in Adults With Autism
# 1907         literal  Depressed Mood Improvement Through Nicotine Do...
#
#      PILabel.xml:lang PILabel.type            PILabel.value
# 0                  en      literal              Alp Ikizler
# 1                  en      literal              Alp Ikizler
# 2                  en      literal              Alp Ikizler
# 3                  en      literal              Alp Ikizler
# 4                  en      literal              Alp Ikizler
# ...               ...          ...                      ...
# 1903               en      literal         Paul A. Newhouse
# 1904               en      literal  Lindsey Colman McKernan
# 1905               en      literal          Stephan Heckers
# 1906               en      literal      Blythe Anne Corbett
# 1907               en      literal         Warren D. Taylor
#
# [1908 rows x 10 columns]

# %% [markdown]
# ## 3.3 Chart of organizations by count of clinical trials ##

# %%
query_string = """
#defaultView:BubbleChart
SELECT (COUNT(DISTINCT ?trial) AS ?count) ?org ?orgLabel 
WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P8329 ?PI .}

  { ?PI wdt:P108 ?org }  
  UNION
  { ?PI wdt:P1416 ?org }  

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?org ?orgLabel 
ORDER BY DESC(?count)"""

result=select(query_string)
result.to_csv("Chart_of_organizations_by_count_of_clinical_trials.csv")
result
# Out:
#    org.type                                 org.value orgLabel.xml:lang  \
# 0       uri     http://www.wikidata.org/entity/Q29052                en
# 1       uri  http://www.wikidata.org/entity/Q89953931                en
# 2       uri  http://www.wikidata.org/entity/Q89953976                en
# 3       uri   http://www.wikidata.org/entity/Q7914455                en
# 4       uri  http://www.wikidata.org/entity/Q89951871                en
# ..      ...                                       ...               ...
# 86      uri   http://www.wikidata.org/entity/Q5547065                en
# 87      uri    http://www.wikidata.org/entity/Q503419                en
# 88      uri   http://www.wikidata.org/entity/Q5611155                en
# 89      uri  http://www.wikidata.org/entity/Q89953915                en
# 90      uri   http://www.wikidata.org/entity/Q5120231                en
#
#    orgLabel.type                                     orgLabel.value  \
# 0        literal                              Vanderbilt University
# 1        literal                  Vanderbilt Department of Medicine
# 2        literal                Vanderbilt Department of Pediatrics
# 3        literal               Vanderbilt University Medical Center
# 4        literal            Vanderbilt Department of Anesthesiology
# ..           ...                                                ...
# 86       literal           Georgetown University School of Medicine
# 87       literal                              University of Arizona
# 88       literal  Kaiser Permanente Washington Health Research I...
# 89       literal               Vanderbilt Department of Dermatology
# 90       literal      Cincinnati Children's Hospital Medical Center
#
#                               count.datatype count.type count.value
# 0   http://www.w3.org/2001/XMLSchema#integer    literal         882
# 1   http://www.w3.org/2001/XMLSchema#integer    literal         445
# 2   http://www.w3.org/2001/XMLSchema#integer    literal          85
# 3   http://www.w3.org/2001/XMLSchema#integer    literal          60
# 4   http://www.w3.org/2001/XMLSchema#integer    literal          48
# ..                                       ...        ...         ...
# 86  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 87  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 88  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 89  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 90  http://www.w3.org/2001/XMLSchema#integer    literal           1
#
# [91 rows x 8 columns]

# %% [markdown]
# ## 3.4 Clinical trials where the sponsor was Pfizer ##

# %%
query_string = """
SELECT ?trial ?trialLabel  WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  { ?trial wdt:P859 wd:Q206921 .}
  UNION
  { ?trial wdt:P8324 wd:Q206921 .}

  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_where_the_sponsor_was_Pfizer.csv")
result
# Out:
#     trial.type                                trial.value trialLabel.xml:lang  \
# 0          uri     http://www.wikidata.org/entity/Q297324                  en
# 1          uri   http://www.wikidata.org/entity/Q61862248                  en
# 2          uri   http://www.wikidata.org/entity/Q61865085                  en
# 3          uri   http://www.wikidata.org/entity/Q61894334                  en
# 4          uri   http://www.wikidata.org/entity/Q61894391                  en
# ..         ...                                        ...                 ...
# 724        uri  http://www.wikidata.org/entity/Q102152880                  en
# 725        uri  http://www.wikidata.org/entity/Q102153068                  en
# 726        uri  http://www.wikidata.org/entity/Q102153289                  en
# 727        uri  http://www.wikidata.org/entity/Q102153533                  en
# 728        uri  http://www.wikidata.org/entity/Q102154051                  en
#
#     trialLabel.type                                   trialLabel.value
# 0           literal                                              ASCOT
# 1           literal  Long Term Safety and Efficacy Study of Tanezum...
# 2           literal  Absorption and Systemic Study of AN2690 in Pat...
# 3           literal  Effect Of Itraconazole On The Pharmacokinetics...
# 4           literal  A Multicenter Phase 3, Open-Label Study of Bos...
# ..              ...                                                ...
# 724         literal  Study to Evaluate the Safety, Tolerability, an...
# 725         literal  BRAF V600E-mutant Colorectal Cancer Study of E...
# 726         literal  Study To Evaluate The Effect Of Two Steady Sta...
# 727         literal  A Study To Asses Mass Balance And Absolute Bio...
# 728         literal  STUDY OF TALAZOPARIB MONOTHERAPY IN CHINESE PA...
#
# [729 rows x 5 columns]

# %% [markdown]
# # 4 Researcher demographics #

# %% [markdown]
# ## 4.1 Count of principal investigators by gender ##

# %%
query_string = """
SELECT (COUNT(?trial) AS ?count) ?gender ?genderLabel WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  # ?trial wdt:P8329 ?pi .
  # ?pi wdt:P21 ?gender .
  # ?pi wikibase:sitelinks ?sl .
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?count  ?gender ?genderLabel"""

result=select(query_string)
result.to_csv("Count_of_principal_investigators_by_gender.csv")
result
# Out:
#                              count.datatype count.type count.value  \
# 0  http://www.w3.org/2001/XMLSchema#integer    literal         613
# 1  http://www.w3.org/2001/XMLSchema#integer    literal         346
#
#   gender.type                             gender.value genderLabel.xml:lang  \
# 0         uri  http://www.wikidata.org/entity/Q6581097                   en
# 1         uri  http://www.wikidata.org/entity/Q6581072                   en
#
#   genderLabel.type genderLabel.value
# 0          literal              male
# 1          literal            female

# %% [markdown]
# ## 4.2 Clinical trials where the principal investigator is female ##

# %%
query_string = """
SELECT ?trial ?trialLabel ?pi ?piLabel ?sl WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  # ?trial wdt:P8329 ?pi .
  # ?pi wdt:P21 wd:Q6581072 .
  # ?pi wikibase:sitelinks ?sl .
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}"""

result=select(query_string)
result.to_csv("Clinical_trials_where_the_principal_investigator_is_female.csv")
result
# Out:
#     trial.type                               trial.value pi.type  \
# 0          uri  http://www.wikidata.org/entity/Q65466006     uri
# 1          uri  http://www.wikidata.org/entity/Q64149990     uri
# 2          uri  http://www.wikidata.org/entity/Q64801405     uri
# 3          uri  http://www.wikidata.org/entity/Q64662092     uri
# 4          uri  http://www.wikidata.org/entity/Q66402861     uri
# ..         ...                                       ...     ...
# 341        uri  http://www.wikidata.org/entity/Q63597543     uri
# 342        uri  http://www.wikidata.org/entity/Q63596706     uri
# 343        uri  http://www.wikidata.org/entity/Q63596709     uri
# 344        uri  http://www.wikidata.org/entity/Q65336883     uri
# 345        uri  http://www.wikidata.org/entity/Q66076530     uri
#
#                                      pi.value  \
# 0    http://www.wikidata.org/entity/Q47161235
# 1    http://www.wikidata.org/entity/Q47493038
# 2    http://www.wikidata.org/entity/Q47493038
# 3    http://www.wikidata.org/entity/Q47502872
# 4    http://www.wikidata.org/entity/Q47744325
# ..                                        ...
# 341  http://www.wikidata.org/entity/Q91133561
# 342  http://www.wikidata.org/entity/Q91133566
# 343  http://www.wikidata.org/entity/Q91133566
# 344  http://www.wikidata.org/entity/Q91133566
# 345  http://www.wikidata.org/entity/Q91133566
#
#                                   sl.datatype  sl.type sl.value  \
# 0    http://www.w3.org/2001/XMLSchema#integer  literal        0
# 1    http://www.w3.org/2001/XMLSchema#integer  literal        1
# 2    http://www.w3.org/2001/XMLSchema#integer  literal        1
# 3    http://www.w3.org/2001/XMLSchema#integer  literal        0
# 4    http://www.w3.org/2001/XMLSchema#integer  literal        0
# ..                                        ...      ...      ...
# 341  http://www.w3.org/2001/XMLSchema#integer  literal        0
# 342  http://www.w3.org/2001/XMLSchema#integer  literal        0
# 343  http://www.w3.org/2001/XMLSchema#integer  literal        0
# 344  http://www.w3.org/2001/XMLSchema#integer  literal        0
# 345  http://www.w3.org/2001/XMLSchema#integer  literal        0
#
#     trialLabel.xml:lang trialLabel.type  \
# 0                    en         literal
# 1                    en         literal
# 2                    en         literal
# 3                    en         literal
# 4                    en         literal
# ..                  ...             ...
# 341                  en         literal
# 342                  en         literal
# 343                  en         literal
# 344                  en         literal
# 345                  en         literal
#
#                                       trialLabel.value piLabel.xml:lang  \
# 0    Pediatric Acute Kidney Injury (AKI) Retrospect...               en
# 1      Levocarnitine for Dry Eye in Sjogren's Syndrome               en
# 2    Memantine for the Treatment of Cognitive Impai...               en
# 3    Reduced Calorie Diet Intervention in Kidney Tr...               en
# 4         Collaboration for Antepartum Risk Evaluation               en
# ..                                                 ...              ...
# 341  Nivolumab Plus Relatlimab or Ipilimumab in Met...               en
# 342  Effect of Providing Stratification of Low Risk...               en
# 343  The Effect of Providing Stratification of Low ...               en
# 344  Immunogenetics of Heparin-Induced Thrombocytop...               en
# 345  Cyclosporine and Etanercept in Stevens-Johnson...               en
#
#     piLabel.type          piLabel.value
# 0        literal     Sara L. Van Driest
# 1        literal     Leslie J. Crofford
# 2        literal     Leslie J. Crofford
# 3        literal      Kelly A. Birdwell
# 4        literal     Julia C. Phillippi
# ..           ...                    ...
# 341      literal      Elizabeth J Davis
# 342      literal  Elizabeth J. Phillips
# 343      literal  Elizabeth J. Phillips
# 344      literal  Elizabeth J. Phillips
# 345      literal  Elizabeth J. Phillips
#
# [346 rows x 13 columns]

# %% [markdown]
# ## 4.3 Principal investigators by occupation ##

# %%
query_string = """
SELECT DISTINCT ?occupation ?occupationLabel (COUNT(?trial) AS ?count) ?sl WHERE {
  # ?trial wdt:P31 wd:Q30612 .
  # ?trial wdt:P8329 ?pi .
  # ?pi wdt:P106 ?occupation .
  # ?occupation wikibase:sitelinks ?sl .
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?count ?occupation ?occupationLabel ?sl
ORDER BY DESC(?count)"""

result=select(query_string)
result.to_csv("Principal_investigators_by_occupation.csv")
result
# Out:
#    occupation.type                          occupation.value  \
# 0              uri   http://www.wikidata.org/entity/Q1650915
# 1              uri  http://www.wikidata.org/entity/Q15401884
# 2              uri   http://www.wikidata.org/entity/Q1622272
# 3              uri     http://www.wikidata.org/entity/Q39631
# 4              uri  http://www.wikidata.org/entity/Q24017632
# 5              uri    http://www.wikidata.org/entity/Q121594
# 6              uri   http://www.wikidata.org/entity/Q1919436
# 7              uri   http://www.wikidata.org/entity/Q3368718
# 8              uri    http://www.wikidata.org/entity/Q212980
# 9              uri   http://www.wikidata.org/entity/Q2114605
# 10             uri    http://www.wikidata.org/entity/Q774306
# 11             uri  http://www.wikidata.org/entity/Q12119633
# 12             uri   http://www.wikidata.org/entity/Q4915128
# 13             uri    http://www.wikidata.org/entity/Q211346
# 14             uri   http://www.wikidata.org/entity/Q3144914
# 15             uri  http://www.wikidata.org/entity/Q16062369
# 16             uri    http://www.wikidata.org/entity/Q336641
# 17             uri   http://www.wikidata.org/entity/Q1113899
# 18             uri  http://www.wikidata.org/entity/Q20107384
# 19             uri    http://www.wikidata.org/entity/Q876864
# 20             uri  http://www.wikidata.org/entity/Q30086937
# 21             uri   http://www.wikidata.org/entity/Q5669847
# 22             uri   http://www.wikidata.org/entity/Q3779582
# 23             uri  http://www.wikidata.org/entity/Q96034777
# 24             uri   http://www.wikidata.org/entity/Q6337803
# 25             uri  http://www.wikidata.org/entity/Q15634281
# 26             uri   http://www.wikidata.org/entity/Q2837942
# 27             uri  http://www.wikidata.org/entity/Q19902880
#
#    occupationLabel.xml:lang occupationLabel.type  occupationLabel.value  \
# 0                        en              literal             researcher
# 1                        en              literal     medical researcher
# 2                        en              literal     university teacher
# 3                        en              literal              physician
# 4                        en              literal          pulmonologist
# 5                        en              literal              professor
# 6                        en              literal           pediatrician
# 7                        en              literal            pathologist
# 8                        en              literal           psychologist
# 9                        en              literal         pharmacologist
# 10                       en              literal                surgeon
# 11                       en              literal           immunologist
# 12                       en              literal   biomedical scientist
# 13                       en              literal           psychiatrist
# 14                       en              literal           hematologist
# 15                       en              literal             oncologist
# 16                       en              literal    emergency physician
# 17                       en              literal  clinical psychologist
# 18                       en              literal          gerontologist
# 19                       en              literal    contributing editor
# 20                       en              literal      cancer researcher
# 21                       en              literal    assistant professor
# 22                       en              literal         microbiologist
# 23                       en              literal           HIV activist
# 24                       en              literal         neuroscientist
# 25                       en              literal             virologist
# 26                       en              literal              allergist
# 27                       en              literal    biomedical engineer
#
#                               count.datatype count.type count.value  \
# 0   http://www.w3.org/2001/XMLSchema#integer    literal         466
# 1   http://www.w3.org/2001/XMLSchema#integer    literal          91
# 2   http://www.w3.org/2001/XMLSchema#integer    literal          52
# 3   http://www.w3.org/2001/XMLSchema#integer    literal          37
# 4   http://www.w3.org/2001/XMLSchema#integer    literal          24
# 5   http://www.w3.org/2001/XMLSchema#integer    literal          18
# 6   http://www.w3.org/2001/XMLSchema#integer    literal          12
# 7   http://www.w3.org/2001/XMLSchema#integer    literal          12
# 8   http://www.w3.org/2001/XMLSchema#integer    literal          10
# 9   http://www.w3.org/2001/XMLSchema#integer    literal          10
# 10  http://www.w3.org/2001/XMLSchema#integer    literal           9
# 11  http://www.w3.org/2001/XMLSchema#integer    literal           6
# 12  http://www.w3.org/2001/XMLSchema#integer    literal           6
# 13  http://www.w3.org/2001/XMLSchema#integer    literal           6
# 14  http://www.w3.org/2001/XMLSchema#integer    literal           5
# 15  http://www.w3.org/2001/XMLSchema#integer    literal           5
# 16  http://www.w3.org/2001/XMLSchema#integer    literal           4
# 17  http://www.w3.org/2001/XMLSchema#integer    literal           3
# 18  http://www.w3.org/2001/XMLSchema#integer    literal           3
# 19  http://www.w3.org/2001/XMLSchema#integer    literal           2
# 20  http://www.w3.org/2001/XMLSchema#integer    literal           2
# 21  http://www.w3.org/2001/XMLSchema#integer    literal           2
# 22  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 23  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 24  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 25  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 26  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 27  http://www.w3.org/2001/XMLSchema#integer    literal           1
#
#                                  sl.datatype  sl.type sl.value
# 0   http://www.w3.org/2001/XMLSchema#integer  literal       32
# 1   http://www.w3.org/2001/XMLSchema#integer  literal        1
# 2   http://www.w3.org/2001/XMLSchema#integer  literal       13
# 3   http://www.w3.org/2001/XMLSchema#integer  literal      156
# 4   http://www.w3.org/2001/XMLSchema#integer  literal        1
# 5   http://www.w3.org/2001/XMLSchema#integer  literal       95
# 6   http://www.w3.org/2001/XMLSchema#integer  literal       12
# 7   http://www.w3.org/2001/XMLSchema#integer  literal       10
# 8   http://www.w3.org/2001/XMLSchema#integer  literal       55
# 9   http://www.w3.org/2001/XMLSchema#integer  literal        4
# 10  http://www.w3.org/2001/XMLSchema#integer  literal       58
# 11  http://www.w3.org/2001/XMLSchema#integer  literal        3
# 12  http://www.w3.org/2001/XMLSchema#integer  literal        4
# 13  http://www.w3.org/2001/XMLSchema#integer  literal       45
# 14  http://www.w3.org/2001/XMLSchema#integer  literal        2
# 15  http://www.w3.org/2001/XMLSchema#integer  literal        2
# 16  http://www.w3.org/2001/XMLSchema#integer  literal        8
# 17  http://www.w3.org/2001/XMLSchema#integer  literal        5
# 18  http://www.w3.org/2001/XMLSchema#integer  literal        1
# 19  http://www.w3.org/2001/XMLSchema#integer  literal       27
# 20  http://www.w3.org/2001/XMLSchema#integer  literal        0
# 21  http://www.w3.org/2001/XMLSchema#integer  literal       16
# 22  http://www.w3.org/2001/XMLSchema#integer  literal       14
# 23  http://www.w3.org/2001/XMLSchema#integer  literal        0
# 24  http://www.w3.org/2001/XMLSchema#integer  literal        7
# 25  http://www.w3.org/2001/XMLSchema#integer  literal        4
# 26  http://www.w3.org/2001/XMLSchema#integer  literal        8
# 27  http://www.w3.org/2001/XMLSchema#integer  literal        0

# %% [markdown]
# # 5 Scope of Wikidata's clinical trials content #

# %% [markdown]
# ## 5.1 List of clinical trials ##

# %%
query_string = """
# List of clinical trials
SELECT ?item ?nct_id ?itemLabel ?phaseLabel ?enrollment ?start_date ?primary_completion_date
WHERE
{
   # ?item p:P31/ps:P31/wdt:P279* wd:Q30612.
   # ?item wdt:P3098 ?nct_id .
   OPTIONAL { ?item wdt:P580  ?start_date }
   OPTIONAL { ?item wdt:P582 ?primary_completion_date }
   OPTIONAL { ?item wdt:P6099 ?phase }
   OPTIONAL { ?item wdt:P1132 ?enrollment }
   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
LIMIT 100"""

result=select(query_string)
result.to_csv("List_of_clinical_trials.csv")
result
# Out:
#    item.type                                item.value nct_id.type  \
# 0        uri  http://www.wikidata.org/entity/Q58846611     literal
# 1        uri  http://www.wikidata.org/entity/Q58846782     literal
# 2        uri  http://www.wikidata.org/entity/Q58846865     literal
# 3        uri  http://www.wikidata.org/entity/Q58846970     literal
# 4        uri  http://www.wikidata.org/entity/Q58847000     literal
# ..       ...                                       ...         ...
# 95       uri  http://www.wikidata.org/entity/Q61862149     literal
# 96       uri  http://www.wikidata.org/entity/Q61862157     literal
# 97       uri  http://www.wikidata.org/entity/Q61862157     literal
# 98       uri  http://www.wikidata.org/entity/Q61862160     literal
# 99       uri  http://www.wikidata.org/entity/Q61862165     literal
#
#    nct_id.value itemLabel.xml:lang itemLabel.type  \
# 0   NCT03339843                 en        literal
# 1   NCT03409848                 en        literal
# 2   NCT03495544                 en        literal
# 3   NCT03571633                 en        literal
# 4   NCT03580070                 en        literal
# ..          ...                ...            ...
# 95  NCT02860000                 en        literal
# 96  NCT02847013                 en        literal
# 97  NCT02847013                 en        literal
# 98  NCT02834780                 en        literal
# 99  NCT02810405                 en        literal
#
#                                       itemLabel.value  \
# 0   Multiorgan Metabolic Imaging Response Assessme...
# 1   Ipilimumab or FOLFOX in Combination With Nivol...
# 2   Study Estimating Association Between Germline ...
# 3   Impact of Pegfilgrastim on Trastuzumab Anti-tu...
# 4   Changes in the Microenvironment of HPV-induced...
# ..                                                ...
# 95  Alisertib With or Without Fulvestrant in Treat...
# 96  The Use of Liposomal Bupivacaine in TAP Blocks...
# 97  The Use of Liposomal Bupivacaine in TAP Blocks...
# 98  Phase 1 Study to Evaluate the Safety, Pharmaco...
# 99  Collection of Tissue Blocks or Slides From Pat...
#
#                           start_date.datatype start_date.type  \
# 0                                         NaN             NaN
# 1                                         NaN             NaN
# 2                                         NaN             NaN
# 3                                         NaN             NaN
# 4                                         NaN             NaN
# ..                                        ...             ...
# 95  http://www.w3.org/2001/XMLSchema#dateTime         literal
# 96  http://www.w3.org/2001/XMLSchema#dateTime         literal
# 97  http://www.w3.org/2001/XMLSchema#dateTime         literal
# 98  http://www.w3.org/2001/XMLSchema#dateTime         literal
# 99  http://www.w3.org/2001/XMLSchema#dateTime         literal
#
#         start_date.value           primary_completion_date.datatype  \
# 0                    NaN                                        NaN
# 1                    NaN                                        NaN
# 2                    NaN                                        NaN
# 3                    NaN                                        NaN
# 4                    NaN                                        NaN
# ..                   ...                                        ...
# 95  2017-07-06T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 96  2019-03-01T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 97  2019-03-01T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 98  2016-07-01T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
# 99  2011-06-10T00:00:00Z  http://www.w3.org/2001/XMLSchema#dateTime
#
#    primary_completion_date.type primary_completion_date.value  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# ..                          ...                           ...
# 95                      literal          2021-12-15T00:00:00Z
# 96                      literal          2019-12-31T00:00:00Z
# 97                      literal          2019-12-31T00:00:00Z
# 98                      literal          2020-06-01T00:00:00Z
# 99                      literal          2023-01-01T00:00:00Z
#
#                          enrollment.datatype enrollment.type enrollment.value  \
# 0                                        NaN             NaN              NaN
# 1                                        NaN             NaN              NaN
# 2                                        NaN             NaN              NaN
# 3                                        NaN             NaN              NaN
# 4                                        NaN             NaN              NaN
# ..                                       ...             ...              ...
# 95  http://www.w3.org/2001/XMLSchema#decimal         literal               96
# 96  http://www.w3.org/2001/XMLSchema#decimal         literal               40
# 97  http://www.w3.org/2001/XMLSchema#decimal         literal               40
# 98  http://www.w3.org/2001/XMLSchema#decimal         literal              128
# 99  http://www.w3.org/2001/XMLSchema#decimal         literal              500
#
#    phaseLabel.xml:lang phaseLabel.type          phaseLabel.value
# 0                  NaN             NaN                       NaN
# 1                  NaN             NaN                       NaN
# 2                  NaN             NaN                       NaN
# 3                  NaN             NaN                       NaN
# 4                  NaN             NaN                       NaN
# ..                 ...             ...                       ...
# 95                  en         literal   phase II clinical trial
# 96                  en         literal   phase II clinical trial
# 97                  en         literal  phase III clinical trial
# 98                  en         literal    phase I clinical trial
# 99                 NaN             NaN                       NaN
#
# [100 rows x 19 columns]

# %% [markdown]
# ## 5.2 Count of clinical trials ##

# %%
query_string = """
# Count clinical trials
SELECT (count(distinct ?item) as ?count)
WHERE {?item p:P31/ps:P31/wdt:P279* wd:Q30612
}"""

result=select(query_string)
result.to_csv("Count_of_clinical_trials.csv")
result
# Out:
#                              count.datatype count.type count.value
# 0  http://www.w3.org/2001/XMLSchema#integer    literal      356915

# %% [markdown]
# ## 5.3 Most common properties applied to clinical trials ##

# %%
query_string = """
SELECT DISTINCT ?property ?propertyLabel ?count
WITH {
  SELECT DISTINCT ?item WHERE {
    # ?item wdt:P31*/wdt:P279* wd:Q30612 .
  }
  LIMIT 400000
  } AS %items 
WITH {
  SELECT DISTINCT ?property (COUNT(*) AS ?count) WHERE {
  INCLUDE %items.
    # ?item ?p [ ] .
    # ?property a wikibase:Property;
                wikibase:claim ?p.
  }
  GROUP BY ?property 
  LIMIT 200
  } AS %results 
WHERE {
  INCLUDE %results.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
ORDER BY DESC(?count)
LIMIT 200"""

result=select(query_string)
result.to_csv("Most_common_properties_applied_to_clinical_trials.csv")
result
# Out:
#     property.type                        property.value  \
# 0             uri    http://www.wikidata.org/entity/P17
# 1             uri    http://www.wikidata.org/entity/P31
# 2             uri  http://www.wikidata.org/entity/P3098
# 3             uri   http://www.wikidata.org/entity/P580
# 4             uri  http://www.wikidata.org/entity/P1132
# ..            ...                                   ...
# 129           uri   http://www.wikidata.org/entity/P585
# 130           uri   http://www.wikidata.org/entity/P576
# 131           uri   http://www.wikidata.org/entity/P508
# 132           uri   http://www.wikidata.org/entity/P287
# 133           uri   http://www.wikidata.org/entity/P268
#
#     propertyLabel.xml:lang propertyLabel.type  \
# 0                       en            literal
# 1                       en            literal
# 2                       en            literal
# 3                       en            literal
# 4                       en            literal
# ..                     ...                ...
# 129                     en            literal
# 130                     en            literal
# 131                     en            literal
# 132                     en            literal
# 133                     en            literal
#
#                          propertyLabel.value  \
# 0                                    country
# 1                                instance of
# 2                      ClinicalTrials.gov ID
# 3                                 start time
# 4                     number of participants
# ..                                       ...
# 129                            point in time
# 130  dissolved, abolished or demolished date
# 131                        BNCF Thesaurus ID
# 132                              designed by
# 133      Bibliothèque nationale de France ID
#
#                                count.datatype count.type count.value
# 0    http://www.w3.org/2001/XMLSchema#integer    literal      405665
# 1    http://www.w3.org/2001/XMLSchema#integer    literal      357284
# 2    http://www.w3.org/2001/XMLSchema#integer    literal      356551
# 3    http://www.w3.org/2001/XMLSchema#integer    literal      351490
# 4    http://www.w3.org/2001/XMLSchema#integer    literal      349638
# ..                                        ...        ...         ...
# 129  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 130  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 131  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 132  http://www.w3.org/2001/XMLSchema#integer    literal           1
# 133  http://www.w3.org/2001/XMLSchema#integer    literal           1
#
# [134 rows x 8 columns]

# %% [markdown]
# ## 5.4 Count of statements in clinical trial records ##

# %%
query_string = """
#defaultView:AreaChart
SELECT ?st ?ct {
  {
   BIND (0 AS ?ct)
   BIND (0 AS ?st)
  }
  UNION {
    SELECT ?st (COUNT(*) as ?ct)
    {
      # ?item wdt:P31*/wdt:P279* wd:Q30612 ; wikibase:statements ?st
    }
    GROUP BY ?st
    ORDER BY ?st
  }
}"""

result=select(query_string)
result.to_csv("Count_of_statements_in_clinical_trial_records.csv")
result
# Out:
#                                   ct.datatype  ct.type ct.value  \
# 0    http://www.w3.org/2001/XMLSchema#integer  literal        0
# 1    http://www.w3.org/2001/XMLSchema#integer  literal      110
# 2    http://www.w3.org/2001/XMLSchema#integer  literal      114
# 3    http://www.w3.org/2001/XMLSchema#integer  literal      119
# 4    http://www.w3.org/2001/XMLSchema#integer  literal      139
# ..                                        ...      ...      ...
# 138  http://www.w3.org/2001/XMLSchema#integer  literal       77
# 139  http://www.w3.org/2001/XMLSchema#integer  literal       79
# 140  http://www.w3.org/2001/XMLSchema#integer  literal       77
# 141  http://www.w3.org/2001/XMLSchema#integer  literal       79
# 142  http://www.w3.org/2001/XMLSchema#integer  literal       80
#
#                                   st.datatype  st.type st.value
# 0    http://www.w3.org/2001/XMLSchema#integer  literal        0
# 1    http://www.w3.org/2001/XMLSchema#integer  literal       42
# 2    http://www.w3.org/2001/XMLSchema#integer  literal       41
# 3    http://www.w3.org/2001/XMLSchema#integer  literal       40
# 4    http://www.w3.org/2001/XMLSchema#integer  literal       39
# ..                                        ...      ...      ...
# 138  http://www.w3.org/2001/XMLSchema#integer  literal       47
# 139  http://www.w3.org/2001/XMLSchema#integer  literal       46
# 140  http://www.w3.org/2001/XMLSchema#integer  literal       45
# 141  http://www.w3.org/2001/XMLSchema#integer  literal       44
# 142  http://www.w3.org/2001/XMLSchema#integer  literal       43
#
# [143 rows x 6 columns]

# %% [markdown]
# ## 5.5 Count of trial records in Wikidata per clinical trial registry ##

# %%
query_string = """
SELECT DISTINCT ?registry ?registryLabel ?count
WITH {
  SELECT DISTINCT ?item WHERE {
    # ?item wdt:P31 wd:Q30612 ;
  }
  LIMIT 400000
} AS %items 
WITH {
  SELECT DISTINCT ?registry ?registryIDitem WHERE {
    # ?registry wdt:P31 wd:Q2138567 .
    # ?registryIDitem wdt:P1535 ?registry .
  }
  GROUP BY ?registry ?registryIDitem
  LIMIT 100
} AS %registries 
WITH {
  SELECT DISTINCT ?registry (COUNT(*) AS ?count) WHERE {
    INCLUDE %items.
    INCLUDE %registries.
    # ?item ?p [ ] .
    # ?property wdt:P1629 ?registryIDitem;
              wikibase:claim ?p.
    # ?property wikibase:propertyType wikibase:ExternalId .
  }
  GROUP BY ?registry 
  LIMIT 100
} AS %results 
WHERE {
  INCLUDE %results.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
ORDER BY DESC(?count)
LIMIT 100"""

result=select(query_string)
result.to_csv("Count_of_trial_records_in_Wikidata_per_clinical_trial_registry.csv")
result
# Out:
#   registry.type                            registry.value  \
# 0           uri   http://www.wikidata.org/entity/Q5133746
# 1           uri  http://www.wikidata.org/entity/Q65242932
# 2           uri  http://www.wikidata.org/entity/Q88374053
#
#   registryLabel.xml:lang registryLabel.type  \
# 0                     en            literal
# 1                     en            literal
# 2                     en            literal
#
#                                registryLabel.value  \
# 0                               ClinicalTrials.gov
# 1  Australian New Zealand Clinical Trials Registry
# 2                  Chinese Clinical Trial Registry
#
#                              count.datatype count.type count.value
# 0  http://www.w3.org/2001/XMLSchema#integer    literal      356517
# 1  http://www.w3.org/2001/XMLSchema#integer    literal          45
# 2  http://www.w3.org/2001/XMLSchema#integer    literal           2
